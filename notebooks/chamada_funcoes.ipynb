# %%
import pandas as pd
import sys

sys.path.append("..")

from analise_dados.load import create_table
import psycopg2

# %%
path_arq = '../csv/online_shopping.csv'
with open(path_arq) as f:
  df = pd.read_csv(f)

path = '../analise_dados/load.py'
create_table(df, 'compras')
# Out:
# Tabela inserida com sucesso
